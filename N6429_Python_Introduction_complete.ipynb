# %% [markdown]
# # Programming with Python Introduction
#
# **Instructions:** Review the online material at links below. Run the code blocks so the output for each code block shows in your notebook. Code blocks in the **Code Challenge** sections require you to enter code before you run it. You need to have the correct output showing for all code cells to receive full credit.
#
# ## W3Schools
#
# We're going to use a resource available online for free to learn basic Python programming. The site is called W3Schools. It's been around a long time. It offers free courses for many web-related technologies, including Python.
#
# ## Review Python Intro
#
# Before beginning any programming, review the W3Schools __[Python Intro](https://www.w3schools.com/python/python_intro.asp)__ page.
#
# ## Review Python Get Started
#
# Watch the video at __[]()__ and follow along while you review the W3Schools __[Python Get Started](https://www.w3schools.com/python/python_getstarted.asp)__ page. Execute the code cells below as you follow the video.
#
# #### Python Install section
#
# You can install Python on your own computer, but it won't be necessary to complete these basic Python learning assignments since you will be completing your assignments using Google Colab.

# %%
# You aren't able to access the terminal directly in the free version of Google Colab.
# Adding an exclamation point before code in Google Colab executes code in the terminal.
# The command below will show what version of Python is installed on this server.
# !python --version
# Out:
# Python 3.13.15

# %% [markdown]
# #### Python Quickstart section
#
# You can actually create and run .py files directly from Google Colab code cells. Rather than have you create and run separate .py files on your own computer, you'll just create and run them here in your Google Colab notebook. You'll still be able to see the output below the code cell.

# %%
# %% at the beginning of a cell in Google Colab is called a cell magic command.
# It tells Colab to apply a specific command to the entire contents of the cell, rather than running it as standard Python code.
# You can see the new file created by clicking on the Files icon (looks like a folder) on the left side of the window.
# %%writefile hello.py
print("Hello")
# Out:
# Writing hello.py

# %%
# We can then use the ! to use Python to execute the code file in the terminal and the output bellow the code cell.
# !python hello.py
# Out:
# Hello

# %% [markdown]
# #### Python Version section

# %%
# Python code entered into code cells in Google Colab should run the same as it does on the W3Schools website.
import sys
print (sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]

# %% [markdown]
# #### The Python Command Line
#
# You can start Python from the terminal (Windows - command line). It will open what is often called the Python interpreter. You will know if you are in the Python interpreter when you see the three >>> symbols instead of the regular terminal prompt. You can execute individual lines of Python code from the Python interpreter. No one uses this to do anything except demonstrate it to beginners. We won't use this again in this course.

# %%
# You can try it out if you want.
# These notebooks weren't built to allow to to interact directly with the Python interpreter.
# You won't be able to type anything.
# If you do try, you'll need to press the square stop button next to this cell a couple of times to get this cell to stop running.
# !python
# Out:
# Python 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# =>>> >
# KeyboardInterrupt
# =>>> ^C

# %% [markdown]
# ## Python Syntax
#
# Review the pages in the __[Python Syntax](https://www.w3schools.com/python/python_syntax.asp)__ section. When you're ready, complete the **Code Challenge** section.
#
# #### Code Challenge
#
# **Instructions**
#
# Inside the editor, complete the following steps:
#
# Write a statement that prints `"Hello World!"`
#
# Write a statement that prints `"Have a good day."`
#
# Write a statement that prints `"Learning Python is fun!"`

# %%
# Print "Hello World!"
print("Hello World.")
# Print "Have a good day."
print("Have a good day.")
# Print "Learning Python is fun!"
print("Learning Python is fun!")
# Out:
# Hello World.
# Have a good day.
# Learning Python is fun!

# %% [markdown]
# ## Submit Your Assignment
#
# * Add "_complete" to the end of the name of this notebook.
# * Save the notebook. (File - Save)
# * Download the notebook. (File - Download - Download .ipynb)
# * Upload your notebook to your GitHub repository. (__[Upload files to GitHub](https://github.com/cmcntsh/N6429_GitHubForClassAssignments#upload-files-directly-to-github)__)
# * Submit your repository link in Canvas.
